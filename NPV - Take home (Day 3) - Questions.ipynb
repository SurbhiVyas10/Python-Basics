# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Take - home
#                         <br> (Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Let's begin with some hands-on practice exercises.
#
# **Create a dataframe wherever necessary**

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Compute minimum and maximum sales for each store and location
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
import pandas as pd
import numpy as np

mylist={'Store':['A','B','A','C','D','A','D','A','C','B'],'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
p=pd.DataFrame(mylist)
p
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
min=pd.pivot_table(p,index='Store',aggfunc=np.min)
min
# Out:
#         Location  Sales
# Store
# A          Delhi  40000
# B           Pune  45000
# C         Mumbai  89000
# D      Hyderabad  85000

# %%
max=pd.pivot_table(p,index='Store',aggfunc=np.max)
max
# Out:
#       Location  Sales
# Store
# A         Pune  87000
# B         Pune  70000
# C       Mumbai  90000
# D         Pune  89000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Find duplicate rows based on the column 'Name'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachin</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
f=[
    ['John',3400,'Sydeny'],
    ['Robert',3000,'Chicago'],
    ['Aadi', 1600, 'New York'],
    ['Robert',3000,'Chicago'],
    ['Robert',3000,'Chicago'],
    ['Robert',3000,'Texas'],
    ['Aadi', 4000,'London'],
    ['Sachine',3000,'Chicago']
]

col_index=['Name','Salary','City']
           
dff=pd.DataFrame(f,columns=col_index)
dff
# Out:
#       Name  Salary      City
# 0     John    3400    Sydeny
# 1   Robert    3000   Chicago
# 2     Aadi    1600  New York
# 3   Robert    3000   Chicago
# 4   Robert    3000   Chicago
# 5   Robert    3000     Texas
# 6     Aadi    4000    London
# 7  Sachine    3000   Chicago

# %%
dff.duplicated(subset='Name') #bydefault: keep='first'
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# dtype: bool

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3.  In column tournament, replace all the 'football' values  with 'cricket' using numpy.where
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
import numpy as np

data = [
    ['Mon','Football'],
    ['Tues','Cricket'],
    ['Wed','Football'],
    ['Thurs','Football'],
    ['Fri','Cricket']    
]

col = ['Days','Tournament']

df2 = pd.DataFrame(data, columns=col)
df2
# Out:
#     Days Tournament
# 0    Mon   Football
# 1   Tues    Cricket
# 2    Wed   Football
# 3  Thurs   Football
# 4    Fri    Cricket

# %%
x=np.where(df2['Tournament'] == 'Football')
print(x)
df2.loc[x[0],'Tournament']='cricket'

df2
# Out:
# (array([0, 2, 3], dtype=int64),)
#     Days Tournament
# 0    Mon    cricket
# 1   Tues    Cricket
# 2    Wed    cricket
# 3  Thurs    cricket
# 4    Fri    Cricket

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Get the descriptive statistics of the sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
d={'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000], 'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']}


df3=pd.DataFrame(d)
df3
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
df3.groupby(by='Seasons').describe()
# Out:
#         Sales                                                                  \
#         count          mean           std      min      25%      50%      75%
# Seasons
# Fall      3.0  56000.000000      0.000000  56000.0  56000.0  56000.0  56000.0
# Spring    3.0  29666.666667   5033.222957  25000.0  27000.0  29000.0  32000.0
# Summer    3.0  70666.666667   6350.852961  67000.0  67000.0  67000.0  72500.0
# Winter    3.0  36333.333333  20647.840888  22000.0  24500.0  27000.0  43500.0
#
#
#              max
# Seasons
# Fall     56000.0
# Spring   35000.0
# Summer   78000.0
# Winter   60000.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Create a new column age with values of your choice. And append it to the below dataframe.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
Name= ['Emma', 'Mia', 'Sophia', 'James', 'John']
maths= [56, 78, 78, 67, 88]
science= [89, 87, 78, 89,  78]
english= [89, 89, 76, 78, 87]
col= ['Name', 'maths', 'science', 'english']
dff= pd.DataFrame(list(zip(Name, maths, science, english)), columns= col)
dff
# Out:
#      Name  maths  science  english
# 0    Emma     56       89       89
# 1     Mia     78       87       89
# 2  Sophia     78       78       76
# 3   James     67       89       78
# 4    John     88       78       87

# %%
a={'Age':(21,23,22,25,24)}
an=pd.DataFrame(a)
d=pd.concat(objs=(dff,an),axis=1)
d
# Out:
#      Name  maths  science  english  Age
# 0    Emma     56       89       89   21
# 1     Mia     78       87       89   23
# 2  Sophia     78       78       76   22
# 3   James     67       89       78   25
# 4    John     88       78       87   24

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Perform right join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#         <td>Geography</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#         <td>History</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
p={'Stud_ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','James'],'MA(Hons)':["History",'English','Geography','German','History']}
r={'Stud_ID':[101,102,103,104,105],'Res_City':['Delhi','Mumbai','Delhi','Chennai','Hyderabad'],'MA(Hons)':['English','History','Fine Arts','German','History']}

df1=pd.DataFrame(p)
df2=pd.DataFrame(r)
df1
# Out:
#    Stud_ID   Name   MA(Hons)
# 0      101   Alex    History
# 1      102    Amy    English
# 2      103  Allen  Geography
# 3      104  Alice     German
# 4      105  James    History

# %%
df2
# Out:
#    Stud_ID   Res_City   MA(Hons)
# 0      101      Delhi    English
# 1      102     Mumbai    History
# 2      103      Delhi  Fine Arts
# 3      104    Chennai     German
# 4      105  Hyderabad    History

# %%
f=pd.merge(df1,df2,on=['Stud_ID','MA(Hons)'],how='right')
f
# Out:
#    Stud_ID   Name   MA(Hons)   Res_City
# 0      104  Alice     German    Chennai
# 1      105  James    History  Hyderabad
# 2      101    NaN    English      Delhi
# 3      102    NaN    History     Mumbai
# 4      103    NaN  Fine Arts      Delhi

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Using the dataframes created in question 6, perform inner join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
f=pd.merge(df1,df2,on=['Stud_ID','MA(Hons)'],how='inner')
f
# Out:
#    Stud_ID   Name MA(Hons)   Res_City
# 0      104  Alice   German    Chennai
# 1      105  James  History  Hyderabad

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8. Concatenate two dataframes along the columns
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
p={'Stud_ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','James']}
r={'Res_City':['Delhi','Mumbai','Delhi','Chennai','Hyderabad'],'MA(Hons)':['English','History','Fine Arts','German','History']}

df1=pd.DataFrame(p)
df1
# Out:
#    Stud_ID   Name
# 0      101   Alex
# 1      102    Amy
# 2      103  Allen
# 3      104  Alice
# 4      105  James

# %%
df2=pd.DataFrame(r)
df2
# Out:
#     Res_City   MA(Hons)
# 0      Delhi    English
# 1     Mumbai    History
# 2      Delhi  Fine Arts
# 3    Chennai     German
# 4  Hyderabad    History

# %%
d=pd.concat(objs=(df1,df2),axis=1)
d
# Out:
#    Stud_ID   Name   Res_City   MA(Hons)
# 0      101   Alex      Delhi    English
# 1      102    Amy     Mumbai    History
# 2      103  Allen      Delhi  Fine Arts
# 3      104  Alice    Chennai     German
# 4      105  James  Hyderabad    History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9. Calculate minimum, maximum and average sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
p={'ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','Ayoung'],'Subject':['Maths','English','Science','German','History']}
r={'ID':[101,102,103,104,105],'Name':['Billy','Brian','Bran','Bryce','Betty'],'MA(Hons)':['English','Science','Social Science','German','History']}

df1=pd.DataFrame(p)
df2=pd.DataFrame(r)
df1
# Out:
#     ID    Name  Subject
# 0  101    Alex    Maths
# 1  102     Amy  English
# 2  103   Allen  Science
# 3  104   Alice   German
# 4  105  Ayoung  History

# %%
df2
# Out:
#     ID   Name        MA(Hons)
# 0  101  Billy         English
# 1  102  Brian         Science
# 2  103   Bran  Social Science
# 3  104  Bryce          German
# 4  105  Betty         History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10. Find all the duplicate entries based on the columns X and Y.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>X</th>
# <th>Y</th>
# <th>Z</th>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>5</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>3</td>
# <td>1</td>
# <td>2</td>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>1</td>
# </tr>
# <tr>
# <td>3</td>
# <td>4</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>2</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>8</td>
# </tr>
#
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
r={'X':[1,2,3,1,2,3,2,2],'Y':[2,2,1,2,2,4,2,2],'Z':[5,6,2,6,1,6,2,8]}
a=pd.DataFrame(r)
a
# Out:
#    X  Y  Z
# 0  1  2  5
# 1  2  2  6
# 2  3  1  2
# 3  1  2  6
# 4  2  2  1
# 5  3  4  6
# 6  2  2  2
# 7  2  2  8

# %%
d={'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000], 'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']}


df3=pd.DataFrame(d)
df3
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
a.set_index('Z', inplace= True)

# %%
a[a.duplicated()]
# Out:
#    X  Y
# Z
# 6  1  2
# 1  2  2
# 2  2  2
# 8  2  2

# %%
df3[df3.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Month, Sales, Seasons]
# Index: []
